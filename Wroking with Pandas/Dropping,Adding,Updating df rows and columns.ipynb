# %%
import pandas as pd

# %%
df1 = pd.read_json("http://pythonhow.com/supermarkets.json")
df1
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df1.drop("City",1)
# Out:
#            Address Country  Employees  ID         Name             State
# 0     3666 21st St     USA          8   1      Madeira          CA 94114
# 1   735 Dolores St     USA         15   2  Bready Shop          CA 94119
# 2      332 Hill St     USA         25   3  Super River  California 94114
# 3     3995 23rd St     USA         10   4   Ben's Shop          CA 94114
# 4  1056 Sanchez St     USA         12   5      Sanchez        California
# 5  551 Alvarado St     USA         20   6   Richvalley          CA 94114

# %%
df1.drop(0,0)
# Out:
#            Address           City Country  Employees  ID         Name  \
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df1
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df1.drop(df1.index[0:3],0)
# Out:
#            Address           City Country  Employees  ID        Name  \
# 3     3995 23rd St  San Francisco     USA         10   4  Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5     Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6  Richvalley
#
#         State
# 3    CA 94114
# 4  California
# 5    CA 94114

# %%
df1.drop(df1.columns[1:3],1)
# Out:
#            Address  Employees  ID         Name             State
# 0     3666 21st St          8   1      Madeira          CA 94114
# 1   735 Dolores St         15   2  Bready Shop          CA 94119
# 2      332 Hill St         25   3  Super River  California 94114
# 3     3995 23rd St         10   4   Ben's Shop          CA 94114
# 4  1056 Sanchez St         12   5      Sanchez        California
# 5  551 Alvarado St         20   6   Richvalley          CA 94114

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df1.columns
# Out:
# Index(['Address', 'City', 'Country', 'Employees', 'ID', 'Name', 'State'], dtype='object')

# %%
df1
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df1["Continent"]=df1.shape[0]*["North America"]
df1
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State      Continent
# 0          CA 94114  North America
# 1          CA 94119  North America
# 2  California 94114  North America
# 3          CA 94114  North America
# 4        California  North America
# 5          CA 94114  North America

# %%
df1.shape
# Out:
# (6, 8)

# %%
df1["Test"] = 6*["test data"]
df1["Test"] = df1["City"]+","+df1["State"]

# %%
df1
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State      Continent                            Test
# 0          CA 94114  North America          San Francisco,CA 94114
# 1          CA 94119  North America          San Francisco,CA 94119
# 2  California 94114  North America  San Francisco,California 94114
# 3          CA 94114  North America          San Francisco,CA 94114
# 4        California  North America        San Francisco,California
# 5          CA 94114  North America          San Francisco,CA 94114

# %%
df1_t = df1.T
df1_t
# Out:
#                                 0                       1  \
# Address              3666 21st St          735 Dolores St
# City                San Francisco           San Francisco
# Country                       USA                     USA
# Employees                       8                      15
# ID                              1                       2
# Name                      Madeira             Bready Shop
# State                    CA 94114                CA 94119
# Continent           North America           North America
# Test       San Francisco,CA 94114  San Francisco,CA 94119
#
#                                         2                       3  \
# Address                       332 Hill St            3995 23rd St
# City                        San Francisco           San Francisco
# Country                               USA                     USA
# Employees                              25                      10
# ...
